# %%
pip install -q yahoo_fin
# Out:
#      |████████████████████████████████| 81 kB 3.8 MB/s
#      |████████████████████████████████| 83 kB 1.8 MB/s
#      |████████████████████████████████| 127 kB 17.7 MB/s
#      |████████████████████████████████| 111 kB 53.6 MB/s
#   Building wheel for fake-useragent (setup.py) ... done
#   Building wheel for parse (setup.py) ... done
#   Building wheel for sgmllib3k (setup.py) ... done
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# datascience 0.10.6 requires folium==0.2.1, but you have folium 0.8.3 which is incompatible.

# %%
mkdir -p data results log

# %%
pip install  git+https://github.com/ahsank/runml#egg=runml
# Out:
# Collecting runml
#   Cloning https://github.com/ahsank/runml to /tmp/pip-install-5taieeiy/runml_bc5a47871c564fb29fa84847a79406f6
#   Running command git clone -q https://github.com/ahsank/runml /tmp/pip-install-5taieeiy/runml_bc5a47871c564fb29fa84847a79406f6
# Building wheels for collected packages: runml
#   Building wheel for runml (setup.py) ... done
#   Created wheel for runml: filename=runml-0.0.4-py3-none-any.whl size=9561 sha256=52c5a3029fe26ae9705ce85f22e2a91f1686d1a9b926f01a733bd2063c8b7a4e
#   Stored in directory: /tmp/pip-ephem-wheel-cache-umih4mj3/wheels/a6/f1/9d/95e87bfdc4a88431e2a1e2de8593e24e721ecc07e52d0b9477
# Successfully built runml
# Installing collected packages: runml
# Successfully installed runml-0.0.4

# %% [markdown]
# Todos:
#
#
#
# 1.   Load previously saved model before training
# 2.   Allow eval only without test/train spliting
# 3.   Incremental data load
# 4.    Add S&P, QQQ etc to the model
# 5. Save model to google drive

# %%
import runml.pipeline
from runml import pipeline,findata
#from importlib import reload
# reload(runml.pipeline)

# %%
findata.EPOCHS=200
pipeline.IS_VERBOSE = False
tickers = [
           'ABNB', 'ACLS', 'AFRM' ,'AI', 'AMBA', 'APO',
           'BILL', 'BMBL', 'CFLT', 'CRCT', 'CRWD',
           'DDOG', 'DOCN', 'DOCS', 'DOCU',
           'ESEA', 'EXPE', 'GLBE', 'GLOB','HSII',
           'INMD', 'JWN', 'LYB',
           'MDB',  'MELI', 'MNDY', 'MPWR',  'MSCI', 'MXL',
           'MTCH', 'MYTE', 'NARI', 'NET', 'NVAX', 'NVCR',
           'OKTA', 'ONDS',
           'PAR', 'RACE','RBLX',  'REGN',
           'SFT', 'SFTBY', 'SHOP', 'SNOW',
           'SPOT', 'STEM', 'STNE', 'SWAV',
           'TDOC', 'TOST','TREX', 'TWLO', 'TWTR', 
           'U','UBER','VRTX', 'Z', 'ZM']
lossfn = "huber_loss"
# lossfn = "mean_squared_error"
# mod = pipeline.RateReturnOnly(pipeline.AddDayMonth())
# df = pipeline.runModelCombined(tickers, 'ipos2b', mod, True)
mod = pipeline.RateReturnOnly(
    pipeline.FeatureSeq([pipeline.AddDayMonth(), pipeline.AddVWap(), pipeline.AddMA(200)]))
df  = pipeline.runModelCombined(tickers, 'ipos2b', mod, True, loss=lossfn)[0]

# %%
df.sort_values('Gain', ascending=False)
# Out:
#    Ticker    Name      Buy     Sell  ...       Error  Gain    Last    Predicted
# 46   STEM  RROnly    88.53   151.07  ...   10.673793  0.55   10.66    16.540001
# 41    SFT  RROnly    22.81    56.43  ...    2.067570  0.41    1.79     2.530000
# 47   STNE  RROnly   438.54   339.54  ...   11.971812  0.38   10.71    14.750000
# 3      AI  RROnly    18.50   268.88  ...   22.964003  0.31   21.19    27.730000
# 39   RBLX  RROnly   243.79   284.16  ...   53.405191  0.31   49.72    65.150002
# 2    AFRM  RROnly   370.09   299.39  ...   41.229765  0.28   37.33    47.900002
# 9    CRCT  RROnly    32.36    59.24  ...   19.067041  0.22   18.28    22.370001
# 50   TOST  RROnly    10.39    15.22  ...   20.589297  0.19   20.87    24.770000
# 55   UBER  RROnly   212.35   258.33  ...   15.849111  0.17   34.68    40.650002
# 8    CFLT  RROnly    55.89    90.38  ...   42.590167  0.16   47.01    54.730000
# 25   MNDY  RROnly    92.70   740.82  ...  191.862363  0.10  194.76   213.490005
# 24   MELI  RROnly  9331.31  8621.61  ...  283.636509  0.10  937.26  1034.930054
# 35   OKTA  RROnly  1665.74  1084.88  ...   42.861473  0.09  164.67   178.979996
# 43   SHOP  RROnly  7845.39  5794.97  ...  142.190107  0.08  656.88   710.390015
# 12   DOCN  RROnly   179.28   307.61  ...   37.666408  0.08   52.08    56.009998
# 49   TDOC  RROnly  1188.03  1550.70  ...   42.436347  0.07   65.00    69.599998
# 45   SPOT  RROnly  1873.45  1375.69  ...  112.068454  0.05  152.27   159.490005
# 7    BMBL  RROnly    59.26   127.84  ...   26.385825  0.05   25.19    26.469999
# 36   ONDS  RROnly    19.78    28.77  ...    4.393193  0.05    4.65     4.890000
# 17   GLBE  RROnly    21.36   179.28  ...   28.269819  0.03   39.69    40.770000
# 54      U  RROnly   271.99   602.60  ...   71.443284  0.03   99.09   102.500000
# 20   INMD  RROnly   267.83   257.97  ...    8.361373 -0.00   41.58    41.419998
# 30   MYTE  RROnly    31.90    50.20  ...   14.725898  0.00   14.43    14.490000
# 10   CRWD  RROnly  1067.97   857.33  ...   37.923567 -0.01  164.93   163.660004
# 52   TWLO  RROnly  2049.72  1198.81  ...   42.887678 -0.02  158.33   155.630005
# 53   TWTR  RROnly   357.37   388.78  ...   23.022630 -0.02   34.32    33.509998
# 56   VRTX  RROnly  1335.50   568.76  ...  149.525017 -0.04  229.61   220.119995
# 57      Z  RROnly   577.86   691.23  ...   27.262565 -0.04   60.81    58.560001
# 14   DOCU  RROnly  1073.39   951.17  ...   41.961944 -0.05  110.28   105.040001
# 37    PAR  RROnly   459.97   378.28  ...   11.469013 -0.05   41.45    39.340000
# 13   DOCS  RROnly    -2.53   231.29  ...   43.825725 -0.06   57.00    53.669998
# 29   MTCH  RROnly   669.58   570.75  ...   35.981373 -0.06  107.56   100.699997
# 5     APO  RROnly   283.55   206.93  ...   20.606825 -0.07   64.17    59.680000
# 31   NARI  RROnly   291.48   336.56  ...   45.155781 -0.08   73.86    67.680000
# 0    ABNB  RROnly   217.31   382.50  ...  128.201082 -0.10  174.90   157.559998
# 22    LYB  RROnly   467.24   521.25  ...   33.703784 -0.11   99.84    88.750000
# 1    ACLS  RROnly   285.28   190.02  ...   14.346841 -0.12   67.55    59.200001
# 42  SFTBY  RROnly   159.12   178.64  ...   13.395152 -0.12   22.09    19.450001
# 44   SNOW  RROnly   575.79   917.25  ...  195.976480 -0.12  273.77   240.119995
# 38   RACE  RROnly  1048.14   625.87  ...   96.595960 -0.12  220.38   193.050003
# 48   SWAV  RROnly   851.94   603.12  ...   27.577348 -0.13  147.49   128.779999
# 11   DDOG  RROnly   725.35   322.57  ...   31.570308 -0.14  159.02   136.250000
# 26   MPWR  RROnly  2337.54  1522.27  ...  108.462518 -0.14  457.35   391.079987
# 40   REGN  RROnly  2748.03  1697.88  ...  280.971380 -0.15  615.13   522.039978
# 28    MXL  RROnly   331.22   162.28  ...    9.141753 -0.16   60.83    51.290001
# 19   HSII  RROnly   252.37   194.52  ...   18.223567 -0.17   43.50    36.310001
# 21    JWN  RROnly   249.40   365.13  ...   12.753963 -0.18   21.61    17.670000
# 51   TREX  RROnly   604.56   498.28  ...   27.468314 -0.18   85.42    69.790001
# 23    MDB  RROnly  3406.35  1853.73  ...   42.321837 -0.20  390.18   311.070007
# 27   MSCI  RROnly  2302.96  1413.48  ...  139.468202 -0.23  527.00   407.230011
# 18   GLOB  RROnly  1641.77   913.62  ...   48.435829 -0.23  259.45   200.919998
# 16   EXPE  RROnly   945.45   618.21  ...   48.470635 -0.23  209.17   161.660004
# 32    NET  RROnly   747.09   425.71  ...   17.234666 -0.24   95.87    73.250000
# 6    BILL  RROnly  1082.81   953.92  ...   34.476590 -0.24  224.23   171.100006
# 58     ZM  RROnly  2123.20  1870.96  ...   69.883389 -0.30  126.96    89.459999
# 15   ESEA  RROnly   201.38   116.65  ...    2.308273 -0.31   30.26    20.830000
# 33   NVAX  RROnly  1834.23  1306.70  ...    9.422031 -0.32   81.89    55.590000
# 4    AMBA  RROnly   847.79   670.54  ...   34.463594 -0.37  134.75    84.300003
# 34   NVCR  RROnly  1138.64   909.32  ...   23.139117 -0.38   76.00    46.970001
#
# [59 rows x 10 columns]

# %%
display(df[["Buy", "Sell", "Total"]].sum())
# mse = 57K, 48K, 105K
# huber = 59, 48, 108K
# Out:
# Buy       59630.09
# Sell      48159.89
# Total    107789.97
# dtype: float64

# %%
findata.EPOCHS=200
tickers1 = ['ARKK', 'ARKW', 'DAPP', 'DTEC', 'EEM', 'FPX',
            'GBTC', 'GLD',
            'ICLN', 'IJR', 'IPO', 'IPOS', 'IWM',
            'JETS', 'KEMQ',
            'MGK', 'MGV', 'MOAT', 'MTUM', 
            'QQQ', 'SLV','SMH', 'SMOG',
            'SPY', 'VNQ', 'VT', 'VTI', 'WDIV',
            'XLB', 'XLC', 'XLE', 'XLF', 'XLI', 'XLK',
            'XLRE', 'XLU', 'XLV', 'XLY', 'XME' ]
# lossfn = "huber_loss"
lossfn = "mean_squared_error"
mod = pipeline.RateReturnOnly(
    pipeline.FeatureSeq([pipeline.AddDayMonth(), pipeline.AddVWap(), pipeline.AddMA(200)]))
# mod = pipeline.RateReturnOnly(pipeline.AddDayMonth())
df1 = pipeline.runModelCombined(tickers1, 'etf2b', mod, True,  loss=lossfn)[0]

# %%
display(df1[0][["Buy", "Sell", "Total", "Accuracy"]].sum())
# huber = 15K, 10K, 25K
# mse =
# Out:
# Buy      14849.25
# Sell      9885.88
# Total    24735.14
# dtype: float64

# %%
df1[0].sort_values('Gain', ascending=False)
# Out:
#    Ticker    Name      Buy    Sell  ...       Error  Gain    Last   Predicted
# 6    GBTC  RROnly   297.65  208.51  ...    4.976015  0.07   27.30   29.080000
# 14   KEMQ  RROnly   125.47  117.25  ...   17.473281  0.05   20.57   21.559999
# 2    DAPP  RROnly    39.11   82.90  ...   12.780233  0.03   13.58   14.010000
# 11   IPOS  RROnly   125.68   98.83  ...   18.208906  0.03   21.97   22.709999
# 29    XLC  RROnly   206.81  124.96  ...   38.664554  0.01   67.41   67.849998
# 10    IPO  RROnly   248.56  221.63  ...   22.344786  0.00   44.46   44.560001
# 19    QQQ  RROnly  1087.34  729.74  ...  143.785908 -0.01  341.51  336.750000
# 3    DTEC  RROnly   179.00  110.88  ...   22.654835 -0.01   40.58   40.290001
# 37    XLY  RROnly   617.28  312.44  ...   87.478565 -0.01  180.00  177.509995
# 12    IWM  RROnly   566.16  664.14  ...   99.573154 -0.01  199.47  197.740005
# 5     FPX  RROnly   485.96  340.19  ...   56.227361 -0.02  104.03  102.250000
# 18   MTUM  RROnly   528.30  325.37  ...   90.474849 -0.03  158.71  154.589996
# 4     EEM  RROnly   143.27  172.72  ...   29.982735 -0.03   48.72   47.189999
# 36    XLV  RROnly   332.74  224.29  ...   73.880511 -0.03  127.51  123.989998
# 20    SLV  RROnly   101.30   68.78  ...   11.506639 -0.03   22.12   21.549999
# 0    ARKK  RROnly   596.43  407.23  ...   34.945869 -0.04   64.80   62.119999
# 7     GLD  RROnly   358.05  303.38  ...  112.675465 -0.04  177.12  169.210007
# 9     IJR  RROnly   340.60  273.08  ...   48.634761 -0.04  106.16  101.489998
# 21    SMH  RROnly   998.49  468.23  ...   81.870377 -0.05  265.25  253.220001
# 23    SPY  RROnly  1253.29  749.45  ...  220.321067 -0.06  434.23  407.130005
# 24    VNQ  RROnly   282.80  207.14  ...   54.417036 -0.06  102.01   95.760002
# 17   MOAT  RROnly   194.78   73.73  ...   37.312067 -0.06   72.05   67.480003
# 27   WDIV  RROnly   162.61   96.26  ...   38.033071 -0.07   67.59   63.180000
# 13   JETS  RROnly   127.86  122.31  ...   12.274188 -0.07   22.56   20.969999
# 15    MGK  RROnly   768.98  353.17  ...   99.097748 -0.09  223.71  203.679993
# 34   XLRE  RROnly   131.65   86.81  ...   24.461776 -0.09   44.68   40.709999
# 33    XLK  RROnly   556.17  209.32  ...   57.059113 -0.09  152.44  138.339996
# 28    XLB  RROnly   231.67  192.09  ...   37.912813 -0.09   83.86   76.199997
# 31    XLF  RROnly   100.88  103.23  ...   17.404939 -0.10   39.22   35.439999
# 32    XLI  RROnly   303.13  235.03  ...   48.486291 -0.10   98.34   88.620003
# 35    XLU  RROnly   185.81  120.18  ...   43.131905 -0.10   66.22   59.349998
# 30    XLE  RROnly   229.83  280.74  ...   22.455460 -0.10   68.05   61.529999
# 22   SMOG  RROnly   706.77  462.52  ...   52.495201 -0.10  133.38  120.410004
# 26    VTI  RROnly   660.76  383.64  ...  109.851077 -0.11  219.37  194.929993
# 25     VT  RROnly   312.19  183.10  ...   53.292549 -0.13  100.28   87.370003
# 8    ICLN  RROnly    97.73   84.95  ...    7.894111 -0.15   18.14   15.510000
# 38    XME  RROnly   195.75  146.19  ...   14.601122 -0.16   49.40   41.560001
# 1    ARKW  RROnly   677.99  372.46  ...   39.737711 -0.19   82.43   66.779999
# 16    MGV  RROnly   290.40  169.01  ...   54.782259 -0.24  104.24   79.239998
#
# [39 rows x 10 columns]

# %%
findata.EPOCHS=200
tickers3 = [
           'AHT', 'AMSC', 'ASTR', 'ATOM',
           'BKKT', 'BGFV', 'BGSF', 'CBNT', 'CLOV', 
           'DNMR', 'ERJ', 'EVGO',
           'FSLY',  'FTCH', 'GOGO', 'HIVE', 
           'ILAL', 'INLX', 'JMIA', 'JOBY',  'KULR', 'MTTR',
           'MYTE', 'NEPH', 'ONDS', 'MQ',
           'PETS', 'PTON', 'SFIX', 'SFT', 'STNE', 
           'ULH', 'VRAR', 'WISH']
lossfn = "huber_loss"
# lossfn = "mean_squared_error"
mod = pipeline.RateReturnOnly(
    pipeline.FeatureSeq([pipeline.AddDayMonth(), pipeline.AddVWap(), pipeline.AddMA(200)]))
# mod = pipeline.RateReturnOnly(pipeline.AddDayMonth())

mod = pipeline.RateReturnOnly(pipeline.AddDayMonth())
df3 = pipeline.runModelCombined(tickers3, 'vols', mod, True, loss=lossfn)[0]

# %%
display(df1[0][["Buy", "Sell", "Total", "Accuracy"]].sum())

# %%
df3.sort_values('Gain', ascending=False)
# Out:
#    Ticker    Name      Buy     Sell    Total  Gain   Last  Predicted
# 7    CBNT  RROnly     1.60     6.90     8.50  2.67   0.02   0.070000
# 0     AHT  RROnly  1664.02  2818.08  4482.10  0.65   9.53  15.730000
# 3    ATOM  RROnly   162.70   169.97   332.67  0.38  17.31  23.950001
# 9    DNMR  RROnly   253.72   141.16   394.88  0.37   3.67   5.020000
# 27   PTON  RROnly   527.12   505.58  1032.70  0.29  29.63  38.110001
# 15   HIVE  RROnly    17.65    18.38    36.03  0.27   1.97   2.490000
# 29    SFT  RROnly    24.77    58.22    82.99  0.24   1.79   2.230000
# 10    ERJ  RROnly    90.67   134.57   225.24  0.23  14.93  18.389999
# 5    BGFV  RROnly   113.68    93.58   207.26  0.22  16.35  20.010000
# 30   STNE  RROnly   346.93   312.22   659.15  0.19  10.71  12.720000
# 21   MTTR  RROnly    44.33    72.27   116.60  0.15   6.83   7.850000
# 33   WISH  RROnly    15.71    48.53    64.24  0.14   2.17   2.480000
# 8    CLOV  RROnly    55.38    58.14   113.52  0.14   2.11   2.410000
# 19   JOBY  RROnly    11.64    27.96    39.60  0.11   4.76   5.300000
# 25     MQ  RROnly    30.98    50.09    81.07  0.10   9.97  10.920000
# 12   FSLY  RROnly   605.91   600.71  1206.62  0.09  18.70  20.410000
# 32   VRAR  RROnly    23.29     5.38    28.67  0.09   8.56   9.340000
# 2    ASTR  RROnly    47.99    71.87   119.86  0.08   3.28   3.530000
# 24   ONDS  RROnly    19.79    38.57    58.36  0.07   4.65   4.970000
# 4    BKKT  RROnly     6.91     6.44    13.35  0.06   5.20   5.490000
# 22   MYTE  RROnly    26.07    64.54    90.61  0.01  14.43  14.630000
# 14   GOGO  RROnly    99.53    79.54   179.07 -0.00  12.96  12.930000
# 11   EVGO  RROnly    34.96    80.59   115.55 -0.01  10.00   9.950000
# 16   ILAL  RROnly     0.57     4.32     4.89 -0.01   0.50   0.500000
# 6    BGSF  RROnly   104.97   156.05   261.01 -0.02  14.21  13.990000
# 23   NEPH  RROnly    54.50    62.80   117.30 -0.04   4.52   4.350000
# 28   SFIX  RROnly   512.53   389.33   901.86 -0.05  12.79  12.190000
# 20   KULR  RROnly    23.03    18.48    41.51 -0.07   2.23   2.070000
# 26   PETS  RROnly   182.05   189.35   371.40 -0.08  25.97  23.980000
# 17   INLX  RROnly    60.96    65.86   126.82 -0.11   6.00   5.310000
# 1    AMSC  RROnly   134.57   144.15   278.72 -0.12   7.68   6.720000
# 31    ULH  RROnly   183.85   159.19   343.04 -0.20  17.77  14.240000
# 13   FTCH  RROnly   272.87   269.34   542.21 -0.29  16.35  11.590000
# 18   JMIA  RROnly   190.47   258.35   448.82 -0.47   8.24   4.360000
