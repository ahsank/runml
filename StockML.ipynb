# %%
pip install -q yahoo_fin

# %%
mkdir -p data results log

# %%
pip install  git+https://github.com/ahsank/runml#egg=runml

# %% [markdown]
# Todos:
#
#
#
# 1.   Load previously saved model before training
# 2.   Allow eval only without test/train spliting
# 3.   Incremental data load
# 4.    Add S&P, QQQ etc to the model
# 5. Save model to google drive

# %%
import runml.pipeline
from runml import pipeline,findata
from google.colab import drive
drive.mount('/content/drive')
#from importlib import reload
# reload(runml.pipeline)
# !cp -r results /content/drive/MyDrive/colab
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
findata.EPOCHS=200
pipeline.IS_VERBOSE = False
tickers = [
           'ABNB', 'ACLS', 'AFRM' ,'AI', 'AMBA', 'APO',
           'BILL', 'BMBL', 'CFLT', 'CRCT', 'COTY', 'CRWD',
           'DDOG', 'DOCN', 'DOCS', 'DOCU',
           'ESEA', 'EXPE', 'GLBE', 'GLOB','HSII',
           'INMD', 'JWN', 'LYB',
           'MDB',  'MELI', 'MNDY', 'MPWR',  'MQ', 'MXL',
           'MTCH', 'MYTE', 'NARI', 'NET', 'NVAX', 'NVCR',
           'OKTA', 'ONDS',
           'PAR', 'RACE','RBLX',  'REGN',
           'SFTBY', 'SHOP', 'SNOW',
           'SPOT', 'STEM', 'STNE', 'SWAV',
           'TDOC', 'TOST','TREX', 'TWLO', 'TWTR', 
           'U','UBER','VRTX', 'Z', 'ZM']
lossfn = "huber_loss"
# lossfn = "mean_squared_error"
# mod = pipeline.RateReturnOnly(pipeline.AddDayMonth())
# df = pipeline.runModelCombined(tickers, 'ipos2b', mod, True)
mod = pipeline.RateReturnOnly(
    pipeline.FeatureSeq([pipeline.AddDayMonth(), pipeline.AddVWap(), pipeline.AddMA(200)]))
df  = pipeline.runModelCombined(tickers, 'ipos2b', mod, False, loss=lossfn)[0]
# !cp -r results /content/drive/MyDrive/colab

# %%
df.sort_values('Gain', ascending=False)
# Out:
#    Ticker    Name      Buy     Sell  ...       Error  Gain    Last    Predicted
# 46   STEM  RROnly    88.53   151.07  ...   10.673793  0.55   10.66    16.540001
# 41    SFT  RROnly    22.81    56.43  ...    2.067570  0.41    1.79     2.530000
# 47   STNE  RROnly   438.54   339.54  ...   11.971812  0.38   10.71    14.750000
# 3      AI  RROnly    18.50   268.88  ...   22.964003  0.31   21.19    27.730000
# 39   RBLX  RROnly   243.79   284.16  ...   53.405191  0.31   49.72    65.150002
# 2    AFRM  RROnly   370.09   299.39  ...   41.229765  0.28   37.33    47.900002
# 9    CRCT  RROnly    32.36    59.24  ...   19.067041  0.22   18.28    22.370001
# 50   TOST  RROnly    10.39    15.22  ...   20.589297  0.19   20.87    24.770000
# 55   UBER  RROnly   212.35   258.33  ...   15.849111  0.17   34.68    40.650002
# 8    CFLT  RROnly    55.89    90.38  ...   42.590167  0.16   47.01    54.730000
# 25   MNDY  RROnly    92.70   740.82  ...  191.862363  0.10  194.76   213.490005
# 24   MELI  RROnly  9331.31  8621.61  ...  283.636509  0.10  937.26  1034.930054
# 35   OKTA  RROnly  1665.74  1084.88  ...   42.861473  0.09  164.67   178.979996
# 43   SHOP  RROnly  7845.39  5794.97  ...  142.190107  0.08  656.88   710.390015
# 12   DOCN  RROnly   179.28   307.61  ...   37.666408  0.08   52.08    56.009998
# 49   TDOC  RROnly  1188.03  1550.70  ...   42.436347  0.07   65.00    69.599998
# 45   SPOT  RROnly  1873.45  1375.69  ...  112.068454  0.05  152.27   159.490005
# 7    BMBL  RROnly    59.26   127.84  ...   26.385825  0.05   25.19    26.469999
# 36   ONDS  RROnly    19.78    28.77  ...    4.393193  0.05    4.65     4.890000
# 17   GLBE  RROnly    21.36   179.28  ...   28.269819  0.03   39.69    40.770000
# 54      U  RROnly   271.99   602.60  ...   71.443284  0.03   99.09   102.500000
# 20   INMD  RROnly   267.83   257.97  ...    8.361373 -0.00   41.58    41.419998
# 30   MYTE  RROnly    31.90    50.20  ...   14.725898  0.00   14.43    14.490000
# 10   CRWD  RROnly  1067.97   857.33  ...   37.923567 -0.01  164.93   163.660004
# 52   TWLO  RROnly  2049.72  1198.81  ...   42.887678 -0.02  158.33   155.630005
# 53   TWTR  RROnly   357.37   388.78  ...   23.022630 -0.02   34.32    33.509998
# 56   VRTX  RROnly  1335.50   568.76  ...  149.525017 -0.04  229.61   220.119995
# 57      Z  RROnly   577.86   691.23  ...   27.262565 -0.04   60.81    58.560001
# 14   DOCU  RROnly  1073.39   951.17  ...   41.961944 -0.05  110.28   105.040001
# 37    PAR  RROnly   459.97   378.28  ...   11.469013 -0.05   41.45    39.340000
# 13   DOCS  RROnly    -2.53   231.29  ...   43.825725 -0.06   57.00    53.669998
# 29   MTCH  RROnly   669.58   570.75  ...   35.981373 -0.06  107.56   100.699997
# 5     APO  RROnly   283.55   206.93  ...   20.606825 -0.07   64.17    59.680000
# 31   NARI  RROnly   291.48   336.56  ...   45.155781 -0.08   73.86    67.680000
# 0    ABNB  RROnly   217.31   382.50  ...  128.201082 -0.10  174.90   157.559998
# 22    LYB  RROnly   467.24   521.25  ...   33.703784 -0.11   99.84    88.750000
# 1    ACLS  RROnly   285.28   190.02  ...   14.346841 -0.12   67.55    59.200001
# 42  SFTBY  RROnly   159.12   178.64  ...   13.395152 -0.12   22.09    19.450001
# 44   SNOW  RROnly   575.79   917.25  ...  195.976480 -0.12  273.77   240.119995
# 38   RACE  RROnly  1048.14   625.87  ...   96.595960 -0.12  220.38   193.050003
# 48   SWAV  RROnly   851.94   603.12  ...   27.577348 -0.13  147.49   128.779999
# 11   DDOG  RROnly   725.35   322.57  ...   31.570308 -0.14  159.02   136.250000
# 26   MPWR  RROnly  2337.54  1522.27  ...  108.462518 -0.14  457.35   391.079987
# 40   REGN  RROnly  2748.03  1697.88  ...  280.971380 -0.15  615.13   522.039978
# 28    MXL  RROnly   331.22   162.28  ...    9.141753 -0.16   60.83    51.290001
# 19   HSII  RROnly   252.37   194.52  ...   18.223567 -0.17   43.50    36.310001
# 21    JWN  RROnly   249.40   365.13  ...   12.753963 -0.18   21.61    17.670000
# 51   TREX  RROnly   604.56   498.28  ...   27.468314 -0.18   85.42    69.790001
# 23    MDB  RROnly  3406.35  1853.73  ...   42.321837 -0.20  390.18   311.070007
# 27   MSCI  RROnly  2302.96  1413.48  ...  139.468202 -0.23  527.00   407.230011
# 18   GLOB  RROnly  1641.77   913.62  ...   48.435829 -0.23  259.45   200.919998
# 16   EXPE  RROnly   945.45   618.21  ...   48.470635 -0.23  209.17   161.660004
# 32    NET  RROnly   747.09   425.71  ...   17.234666 -0.24   95.87    73.250000
# 6    BILL  RROnly  1082.81   953.92  ...   34.476590 -0.24  224.23   171.100006
# 58     ZM  RROnly  2123.20  1870.96  ...   69.883389 -0.30  126.96    89.459999
# 15   ESEA  RROnly   201.38   116.65  ...    2.308273 -0.31   30.26    20.830000
# 33   NVAX  RROnly  1834.23  1306.70  ...    9.422031 -0.32   81.89    55.590000
# 4    AMBA  RROnly   847.79   670.54  ...   34.463594 -0.37  134.75    84.300003
# 34   NVCR  RROnly  1138.64   909.32  ...   23.139117 -0.38   76.00    46.970001
#
# [59 rows x 10 columns]

# %%
display(df[["Buy", "Sell", "Total"]].sum())
# mse = 57K, 48K, 105K
# huber = 59, 48, 108K
# Out:
# Buy       59630.09
# Sell      48159.89
# Total    107789.97
# dtype: float64

# %%
findata.EPOCHS=200
tickers1 = ['ARKK', 'ARKW', 'DAPP', 'DTEC', 'EEM', 'FPX',
            'GBTC', 'GLD',
            'ICLN', 'IJR', 'IPO', 'IPOS', 'IWM',
            'JETS', 'KEMQ',
            'MGK', 'MGV', 'MOAT', 'MTUM', 
            'QQQ', 'SLV','SMH', 'SMOG',
            'SPY', 'VNQ', 'VT', 'VTI', 'WDIV',
            'XLB', 'XLC', 'XLE', 'XLF', 'XLI', 'XLK',
            'XLRE', 'XLU', 'XLV', 'XLY', 'XME' ]
# lossfn = "huber_loss"
lossfn = "mean_squared_error"
mod = pipeline.RateReturnOnly(
    pipeline.FeatureSeq([pipeline.AddDayMonth(), pipeline.AddVWap(), pipeline.AddMA(200)]))
# mod = pipeline.RateReturnOnly(pipeline.AddDayMonth())
df1 = pipeline.runModelCombined(tickers1, 'etf2b', mod, False,  loss=lossfn)[0]
# !cp -r results /content/drive/MyDrive/colab

# %%
display(df1[["Buy", "Sell", "Total", "Accuracy"]].mean())
# huber = 15K, 10K, 25K
# mse = 15K, 10K, 25K
# Out:
# Buy         386.758718
# Sell        255.307692
# Total       642.065641
# Accuracy      0.883347
# dtype: float64

# %%
df1.sort_values('Gain', ascending=False)
# Out:
#    Ticker    Name      Buy    Sell  ...       Error  Gain    Last   Predicted
# 14   KEMQ  RROnly   110.71  123.01  ...   17.407043  0.24   20.57   25.590000
# 6    GBTC  RROnly   294.69  250.75  ...    4.890406  0.21   27.30   33.009998
# 10    IPO  RROnly   257.63  239.80  ...   22.466209  0.08   44.46   47.830002
# 2    DAPP  RROnly    40.93   72.85  ...   12.609284  0.06   13.58   14.390000
# 11   IPOS  RROnly    79.42  111.74  ...   18.256214  0.04   21.97   22.750000
# 22   SMOG  RROnly   616.95  365.16  ...   52.460029  0.02  133.38  136.669998
# 1    ARKW  RROnly   709.24  490.26  ...   39.842118  0.02   82.43   84.470001
# 0    ARKK  RROnly   599.98  514.29  ...   34.929155 -0.01   64.80   64.300003
# 3    DTEC  RROnly   181.47   98.80  ...   22.646814 -0.03   40.58   39.540001
# 20    SLV  RROnly    94.81   58.71  ...   11.492340 -0.03   22.12   21.440001
# 4     EEM  RROnly   154.74  116.30  ...   30.003769 -0.04   48.72   46.860001
# 17   MOAT  RROnly   181.79  135.12  ...   37.365699 -0.06   72.05   67.650002
# 7     GLD  RROnly   351.24  248.05  ...  112.749440 -0.06  177.12  165.679993
# 27   WDIV  RROnly   155.90  101.75  ...   37.978748 -0.06   67.59   63.740002
# 18   MTUM  RROnly   466.38  425.22  ...   90.578306 -0.06  158.71  149.720001
# 36    XLV  RROnly   321.44  209.44  ...   73.681993 -0.07  127.51  118.230003
# 19    QQQ  RROnly  1144.72  564.70  ...  144.004247 -0.07  341.51  316.160004
# 13   JETS  RROnly   128.42  171.28  ...   12.348453 -0.07   22.56   21.020000
# 8    ICLN  RROnly    92.65   66.36  ...    7.912737 -0.08   18.14   16.660000
# 12    IWM  RROnly   818.32  579.64  ...   99.544761 -0.08  199.47  183.570007
# 28    XLB  RROnly   259.99  184.18  ...   37.906730 -0.09   83.86   76.230003
# 30    XLE  RROnly   290.16  296.22  ...   22.243358 -0.09   68.05   61.779999
# 29    XLC  RROnly   187.41  170.11  ...   38.699439 -0.09   67.41   61.459999
# 15    MGK  RROnly   746.05  398.82  ...   99.528162 -0.09  223.71  202.720001
# 37    XLY  RROnly   631.84  315.85  ...   87.886255 -0.09  180.00  163.690002
# 24    VNQ  RROnly   329.88  175.63  ...   54.447285 -0.09  102.01   92.330002
# 23    SPY  RROnly  1186.46  620.55  ...  220.203125 -0.09  434.23  395.619995
# 9     IJR  RROnly   394.60  273.29  ...   48.663701 -0.09  106.16   96.809998
# 31    XLF  RROnly   110.06   85.00  ...   17.430714 -0.10   39.22   35.340000
# 21    SMH  RROnly  1127.03  620.32  ...   82.273337 -0.11  265.25  237.240005
# 34   XLRE  RROnly   155.01   92.55  ...   24.455479 -0.12   44.68   39.230000
# 26    VTI  RROnly   664.62  405.70  ...  110.177055 -0.12  219.37  193.679993
# 35    XLU  RROnly   186.61  105.48  ...   43.034244 -0.12   66.22   58.000000
# 5     FPX  RROnly   430.68  322.31  ...   56.330087 -0.15  104.03   88.580002
# 38    XME  RROnly   199.05  136.28  ...   14.649168 -0.16   49.40   41.439999
# 33    XLK  RROnly   578.25  247.67  ...   57.437430 -0.16  152.44  128.199997
# 32    XLI  RROnly   288.12  238.32  ...   48.506219 -0.16   98.34   82.379997
# 25     VT  RROnly   256.47  203.66  ...   53.394711 -0.17  100.28   82.870003
# 16    MGV  RROnly   259.87  121.83  ...   54.861224 -0.30  104.24   73.199997
#
# [39 rows x 10 columns]

# %%
findata.EPOCHS=200
tickers3 = [
           'AHT', 'AMSC', 'ASTR', 'ATOM',
           'BKKT', 'BGFV', 'BGSF', 'CBNT', 'CLOV', 
           'DNMR', 'DMTK', 'ERJ', 'EVGO',
           'FSLY',  'FTCH', 'GOGO', 'HIVE', 
           'ILAL', 'INLX', 'JMIA', 'JOBY',  'KULR', 'MTTR',
           'MYTE', 'NEPH', 'ONDS', 'MQ',
           'PETS', 'PTON', 'SFIX', 'STEM', 'SFT', 'STNE', 
           'VRAR', 'WISH']
lossfn = "huber_loss"
# lossfn = "mean_squared_error"
mod = pipeline.RateReturnOnly(
    pipeline.FeatureSeq([pipeline.AddDayMonth(), pipeline.AddVWap(), pipeline.AddMA(200)]))
# mod = pipeline.RateReturnOnly(pipeline.AddDayMonth())
df3 = pipeline.runModelCombined(tickers3, 'vols', mod, True, loss=lossfn)[0]
# !cp -r results /content/drive/MyDrive/colab

# %%
display(df3[["Buy", "Sell", "Total", "Accuracy"]].mean())
# Out:
# Buy         160.839706
# Sell        235.162647
# Total       396.002059
# Accuracy      0.835326
# dtype: float64

# %%
df3.sort_values('Gain', ascending=False)
# Out:
#    Ticker    Name      Buy     Sell  ...      Error  Gain   Last  Predicted
# 7    CBNT  RROnly     0.24     5.70  ...   0.095429  3.71   0.02   0.090000
# 18   JMIA  RROnly   175.57   255.08  ...   3.761087  1.43   8.24  20.030001
# 0     AHT  RROnly  1385.01  3532.37  ...  19.604399  0.95   9.53  18.620001
# 12   FSLY  RROnly   443.34   699.79  ...  13.497181  0.73  18.70  32.389999
# 15   HIVE  RROnly    23.98    17.16  ...   0.144634  0.46   1.97   2.880000
# 4    BKKT  RROnly     3.33    11.66  ...   3.957485  0.23   5.20   6.380000
# 19   JOBY  RROnly     3.84    43.14  ...   3.958950  0.23   4.76   5.840000
# 30   STNE  RROnly   449.27   286.93  ...  12.615401  0.19  10.71  12.770000
# 29    SFT  RROnly    22.36    53.15  ...   2.061895  0.18   1.79   2.110000
# 8    CLOV  RROnly    28.77    57.28  ...   2.578051  0.18   2.11   2.490000
# 33   WISH  RROnly    26.78    45.86  ...   2.627351  0.17   2.17   2.540000
# 2    ASTR  RROnly    39.27    68.17  ...   3.740072  0.16   3.28   3.820000
# 9    DNMR  RROnly   209.73   180.64  ...   5.138526  0.14   3.67   4.190000
# 27   PTON  RROnly   364.97   625.59  ...  22.838611  0.14  29.63  33.849998
# 25     MQ  RROnly    11.13    59.72  ...  10.487503  0.11   9.97  11.050000
# 1    AMSC  RROnly   125.42   141.47  ...   5.185536  0.09   7.68   8.360000
# 21   MTTR  RROnly    35.66    84.34  ...   7.355142  0.09   6.83   7.420000
# 23   NEPH  RROnly    65.32    53.43  ...   3.673638  0.06   4.52   4.770000
# 28   SFIX  RROnly   545.40   453.85  ...  13.170303  0.04  12.79  13.240000
# 16   ILAL  RROnly     1.25     3.69  ...   0.475162  0.03   0.50   0.520000
# 22   MYTE  RROnly    25.68    46.84  ...  14.804675  0.02  14.43  14.730000
# 32   VRAR  RROnly    25.50    19.16  ...   7.693741 -0.01   8.56   8.510000
# 6    BGSF  RROnly   115.88   112.44  ...   6.222291 -0.02  14.21  13.890000
# 24   ONDS  RROnly    27.40    27.41  ...   4.506665 -0.04   4.65   4.480000
# 14   GOGO  RROnly   112.43    76.47  ...   1.797904 -0.06  12.96  12.230000
# 17   INLX  RROnly    50.91    55.50  ...   0.348457 -0.08   6.00   5.510000
# 10    ERJ  RROnly    87.11   135.72  ...   4.623561 -0.11  14.93  13.320000
# 13   FTCH  RROnly   262.39   249.22  ...   8.177790 -0.17  16.35  13.520000
# 3    ATOM  RROnly   221.55   126.31  ...   3.309386 -0.18  17.31  14.190000
# 11   EVGO  RROnly    46.86    56.84  ...   7.930363 -0.18  10.00   8.190000
# 31    ULH  RROnly   149.07   147.62  ...  11.692283 -0.25  17.77  13.340000
# 5    BGFV  RROnly   166.97   106.72  ...   1.283728 -0.26  16.35  12.180000
# 26   PETS  RROnly   197.45   134.59  ...  14.269551 -0.33  25.97  17.350000
# 20   KULR  RROnly    18.71    21.67  ...   0.914945 -0.34   2.23   1.480000
#
# [34 rows x 10 columns]
